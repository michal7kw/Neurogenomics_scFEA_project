# %% [markdown]
# # Code For Debugging

# %% [markdown]
# import torch
#
# # Check if CUDA is available
# cuda_available = torch.cuda.is_available()
#
# print(f"CUDA available: {cuda_available}")
#
# # If CUDA is available, print the number of CUDA devices and their names
# if cuda_available:
#     print(f"Number of CUDA devices: {torch.cuda.device_count()}")
#     for i in range(torch.cuda.device_count()):
#         print(f"CUDA Device {i}: {torch.cuda.get_device_name(i)}")

# %%
conda --version
# Out:
# conda 4.11.0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init bash
# Out:
# no change     /opt/python/miniconda/condabin/conda
# no change     /opt/python/miniconda/bin/conda
# no change     /opt/python/miniconda/bin/conda-env
# no change     /opt/python/miniconda/bin/activate
# no change     /opt/python/miniconda/bin/deactivate
# no change     /opt/python/miniconda/etc/profile.d/conda.sh
# no change     /opt/python/miniconda/etc/fish/conf.d/conda.fish
# no change     /opt/python/miniconda/shell/condabin/Conda.psm1
# no change     /opt/python/miniconda/shell/condabin/conda-hook.ps1
# no change     /opt/python/miniconda/lib/python3.9/site-packages/xontrib/conda.xsh
# no change     /opt/python/miniconda/etc/profile.d/conda.csh
# no change     /home/michal.kubacki/.bashrc
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda info
# Out:
#      active environment : None
#        user config file : /home/michal.kubacki/.condarc
#  populated config files : /home/michal.kubacki/.condarc
#           conda version : 4.11.0
#     conda-build version : not installed
#          python version : 3.9.7.final.0
#        virtual packages : __cuda=12.0=0
#                           __linux=4.18.0=0
#                           __glibc=2.28=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /opt/python/miniconda  (read only)
#       conda av data dir : /opt/python/miniconda/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://conda.anaconda.org/conda-forge/linux-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://conda.anaconda.org/nodefaults/linux-64
#                           https://conda.anaconda.org/nodefaults/noarch
#           package cache : /opt/python/miniconda/pkgs
#                           /home/michal.kubacki/.conda/pkgs
#        envs directories : /home/michal.kubacki/.conda/envs
#                           /opt/python/miniconda/envs
#                platform : linux-64
#              user-agent : conda/4.11.0 requests/2.27.1 CPython/3.9.7 Linux/4.18.0-305.3.1.el8.x86_64 centos/8.4.2105 glibc/2.28
#                 UID:GID : 10666:1203
#              netrc file : None
#            offline mode : False
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda env list
# Out:
# # conda environments:
# #
#                          /home/michal.kubacki/miniconda3
#                          /home/michal.kubacki/miniconda3/envs/r-reticulate
#                          /home/michal.kubacki/miniconda3/envs/r-reticulate/envs/r-reticulate
# base                  *  /opt/python/miniconda
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
ls
# Out:
#  data/                  output/                 script.sbatch
#  doc/                   result/                 scWGCNA.R
#  flowchart.png          scFEA_cl.py            'single analysis by seurat.R'
#  input/                 scFEA_debugging.ipynb   src/
#  job_name_8479341.log   scfea.sh

# %%
conda install --file ./input/requirements
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 24.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/python/3.9.15
#
#   added / updated specs:
#     - numpy[version='>=1.15.4']
#     - pandas[version='>=0.23.4']
#     - tqdm[version='>=4.28.1']
#     - umap-learn[version='>=0.5.1']
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anyio-3.5.0                |   py39h06a4308_0         167 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py39h7f8727e_0          33 KB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     attrs-23.1.0               |   py39h06a4308_0         140 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     backports-1.1              |     pyhd3eb1b0_0           4 KB
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     beautifulsoup4-4.12.2      |   py39h06a4308_0         209 KB
#     blas-1.0                   |              mkl           6 KB
#     bleach-4.1.0               |     pyhd3eb1b0_0         123 KB
#     bottleneck-1.3.5           |   py39h7deecbd_0         115 KB
#     ca-certificates-2023.12.12 |       h06a4308_0         126 KB
#     cffi-1.16.0                |   py39h5eee18b_0         251 KB
#     comm-0.1.2                 |   py39h06a4308_0          13 KB
#     debugpy-1.6.7              |   py39h6a678d5_0         2.0 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     defusedxml-0.7.1           |     pyhd3eb1b0_0          23 KB
#     entrypoints-0.4            |   py39h06a4308_0          16 KB
#     exceptiongroup-1.2.0       |   py39h06a4308_0          29 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     idna-3.4                   |   py39h06a4308_0          93 KB
#     importlib-metadata-7.0.1   |   py39h06a4308_0          40 KB
#     importlib_resources-6.1.1  |   py39h06a4308_1          54 KB
#     intel-openmp-2023.1.0      |   hdb19cb5_46306        17.2 MB
#     ipykernel-6.25.0           |   py39h2f386ee_0         228 KB
#     ipython-8.15.0             |   py39h06a4308_0         1.1 MB
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB
#     jedi-0.18.1                |   py39h06a4308_1         982 KB
#     jinja2-3.1.3               |   py39h06a4308_0         269 KB
#     joblib-1.2.0               |   py39h06a4308_0         396 KB
#     jsonschema-4.19.2          |   py39h06a4308_0         142 KB
#     jsonschema-specifications-2023.7.1|   py39h06a4308_0          15 KB
#     jupyter_client-7.4.9       |   py39h06a4308_0         205 KB
#     jupyter_core-5.5.0         |   py39h06a4308_0          76 KB
#     jupyter_server-1.23.4      |   py39h06a4308_0         382 KB
#     jupyterlab_pygments-0.2.2  |   py39h06a4308_0          17 KB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     libllvm14-14.0.6           |       hdb19cb5_3        33.4 MB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     llvmlite-0.42.0            |   py39h6a678d5_0         3.7 MB
#     matplotlib-inline-0.1.6    |   py39h06a4308_0          16 KB
#     mistune-2.0.4              |   py39h06a4308_0          92 KB
#     mkl-2023.1.0               |   h213fc3f_46344       171.5 MB
#     mkl-service-2.4.0          |   py39h5eee18b_1          54 KB
#     mkl_fft-1.3.8              |   py39h5eee18b_0         216 KB
#     mkl_random-1.2.4           |   py39hdb19cb5_0         313 KB
#     nb_conda-2.2.1             |   py39h06a4308_1          33 KB
#     nb_conda_kernels-2.3.1     |   py39h06a4308_0          33 KB
#     nbclassic-1.0.0            |   py39h06a4308_0         6.1 MB
#     nbclient-0.8.0             |   py39h06a4308_0          97 KB
#     nbconvert-7.10.0           |   py39h06a4308_0         472 KB
#     nbconvert-core-7.10.0      |     pyhd8ed1ab_0         184 KB  conda-forge
#     nbformat-5.9.2             |   py39h06a4308_0         136 KB
#     nest-asyncio-1.5.6         |   py39h06a4308_0          14 KB
#     notebook-6.5.4             |   py39h06a4308_1         532 KB
#     notebook-shim-0.2.3        |   py39h06a4308_0          22 KB
#     numba-0.59.0               |   py39h6a678d5_0         4.4 MB
#     numexpr-2.8.7              |   py39h85018f9_0         140 KB
#     numpy-1.26.3               |   py39h5f9d8c6_0          10 KB
#     numpy-base-1.26.3          |   py39hb5e798b_0         7.2 MB
#     packaging-23.1             |   py39h06a4308_0          77 KB
#     pandas-2.1.4               |   py39h1128e8f_0        12.4 MB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     pkgutil-resolve-name-1.3.10|   py39h06a4308_1          10 KB
#     platformdirs-3.10.0        |   py39h06a4308_0          33 KB
#     prometheus_client-0.14.1   |   py39h06a4308_0          90 KB
#     prompt-toolkit-3.0.43      |   py39h06a4308_0         571 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     psutil-5.9.0               |   py39h5eee18b_0         330 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     pygments-2.15.1            |   py39h06a4308_1         1.7 MB
#     pynndescent-0.5.10         |   py39h06a4308_0          95 KB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     python-fastjsonschema-2.16.2|   py39h06a4308_0         231 KB
#     python-tzdata-2023.3       |     pyhd3eb1b0_0         140 KB
#     pytz-2023.3.post1          |   py39h06a4308_0         210 KB
#     pyzmq-23.2.0               |   py39h6a678d5_0         445 KB
#     referencing-0.30.2         |   py39h06a4308_0          61 KB
#     rpds-py-0.10.6             |   py39hb02cf49_0        1007 KB
#     scikit-learn-1.3.0         |   py39h1128e8f_1         8.4 MB
#     scipy-1.11.4               |   py39h5f9d8c6_0        20.3 MB
#     send2trash-1.8.2           |   py39h06a4308_0          27 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     sniffio-1.3.0              |   py39h06a4308_0          16 KB
#     soupsieve-2.5              |   py39h06a4308_0          69 KB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     tbb-2021.8.0               |       hdb19cb5_0         1.6 MB
#     terminado-0.17.1           |   py39h06a4308_0          31 KB
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB
#     tinycss2-1.2.1             |   py39h06a4308_0          39 KB
#     tornado-6.3.3              |   py39h5eee18b_0         635 KB
#     tqdm-4.65.0                |   py39hb070fc8_0         131 KB
#     traitlets-5.7.1            |   py39h06a4308_0         200 KB
#     typing-extensions-4.9.0    |   py39h06a4308_1           9 KB
#     typing_extensions-4.9.0    |   py39h06a4308_1          54 KB
#     umap-learn-0.5.3           |   py39h06a4308_0         137 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     webencodings-0.5.1         |   py39h06a4308_1          20 KB
#     websocket-client-0.58.0    |   py39h06a4308_4          66 KB
#     zeromq-4.3.5               |       h6a678d5_0         366 KB
#     zipp-3.17.0                |   py39h06a4308_0          21 KB
#     ------------------------------------------------------------
#                                            Total:       305.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.5-py39h7deecbd_0
#   comm               pkgs/main/linux-64::comm-0.1.2-py39h06a4308_0
#   debugpy            pkgs/main/linux-64::debugpy-1.6.7-py39h6a678d5_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2023.1.0-hdb19cb5_46306
#   joblib             pkgs/main/linux-64::joblib-1.2.0-py39h06a4308_0
#   jsonschema-specif~ pkgs/main/linux-64::jsonschema-specifications-2023.7.1-py39h06a4308_0
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-11.2.0-h00389a5_1
#   libgfortran5       pkgs/main/linux-64::libgfortran5-11.2.0-h1234567_1
#   libllvm14          pkgs/main/linux-64::libllvm14-14.0.6-hdb19cb5_3
#   llvmlite           pkgs/main/linux-64::llvmlite-0.42.0-py39h6a678d5_0
#   mkl                pkgs/main/linux-64::mkl-2023.1.0-h213fc3f_46344
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py39h5eee18b_1
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.8-py39h5eee18b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.4-py39hdb19cb5_0
#   nbconvert          pkgs/main/linux-64::nbconvert-7.10.0-py39h06a4308_0
#   numba              pkgs/main/linux-64::numba-0.59.0-py39h6a678d5_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.7-py39h85018f9_0
#   numpy              pkgs/main/linux-64::numpy-1.26.3-py39h5f9d8c6_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.26.3-py39hb5e798b_0
#   pandas             pkgs/main/linux-64::pandas-2.1.4-py39h1128e8f_0
#   psutil             pkgs/main/linux-64::psutil-5.9.0-py39h5eee18b_0
#   pynndescent        pkgs/main/linux-64::pynndescent-0.5.10-py39h06a4308_0
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#   pytz               pkgs/main/linux-64::pytz-2023.3.post1-py39h06a4308_0
#   referencing        pkgs/main/linux-64::referencing-0.30.2-py39h06a4308_0
#   rpds-py            pkgs/main/linux-64::rpds-py-0.10.6-py39hb02cf49_0
#   scikit-learn       pkgs/main/linux-64::scikit-learn-1.3.0-py39h1128e8f_1
#   scipy              pkgs/main/linux-64::scipy-1.11.4-py39h5f9d8c6_0
#   tbb                pkgs/main/linux-64::tbb-2021.8.0-hdb19cb5_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#   tqdm               pkgs/main/linux-64::tqdm-4.65.0-py39hb070fc8_0
#   umap-learn         pkgs/main/linux-64::umap-learn-0.5.3-py39h06a4308_0
#
# The following packages will be UPDATED:
#
#   backports          conda-forge::backports-1.0-pyhd8ed1ab~ --> pkgs/main::backports-1.1-pyhd3eb1b0_0
#   ca-certificates    conda-forge::ca-certificates-2023.7.2~ --> pkgs/main::ca-certificates-2023.12.12-h06a4308_0
#   cffi               conda-forge::cffi-1.15.0-py39h4bc2ebd~ --> pkgs/main::cffi-1.16.0-py39h5eee18b_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.~ --> pkgs/main/linux-64::exceptiongroup-1.2.0-py39h06a4308_0
#   importlib-metadata conda-forge/noarch::importlib-metadat~ --> pkgs/main/linux-64::importlib-metadata-7.0.1-py39h06a4308_0
#   importlib_resourc~ conda-forge/noarch::importlib_resourc~ --> pkgs/main/linux-64::importlib_resources-6.1.1-py39h06a4308_1
#   ipykernel          conda-forge::ipykernel-5.5.5-py39hef5~ --> pkgs/main::ipykernel-6.25.0-py39h2f386ee_0
#   jinja2             conda-forge/noarch::jinja2-3.1.2-pyhd~ --> pkgs/main/linux-64::jinja2-3.1.3-py39h06a4308_0
#   jsonschema         conda-forge/noarch::jsonschema-4.17.3~ --> pkgs/main/linux-64::jsonschema-4.19.2-py39h06a4308_0
#   jupyter_client     conda-forge/noarch::jupyter_client-7.~ --> pkgs/main/linux-64::jupyter_client-7.4.9-py39h06a4308_0
#   jupyter_core       conda-forge::jupyter_core-5.3.2-py39h~ --> pkgs/main::jupyter_core-5.5.0-py39h06a4308_0
#   nbconvert-core                         7.8.0-pyhd8ed1ab_0 --> 7.10.0-pyhd8ed1ab_0
#   pexpect            conda-forge::pexpect-4.8.0-pyh1a96a4e~ --> pkgs/main::pexpect-4.8.0-pyhd3eb1b0_3
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.~ --> pkgs/main/linux-64::prompt-toolkit-3.0.43-py39h06a4308_0
#   prompt_toolkit     conda-forge::prompt_toolkit-3.0.39-hd~ --> pkgs/main::prompt_toolkit-3.0.43-hd3eb1b0_0
#   ptyprocess         conda-forge::ptyprocess-0.7.0-pyhd3de~ --> pkgs/main::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pyzmq              conda-forge::pyzmq-19.0.2-py39hb69f2a~ --> pkgs/main::pyzmq-23.2.0-py39h6a678d5_0
#   six                  conda-forge::six-1.16.0-pyh6c4a22f_0 --> pkgs/main::six-1.16.0-pyhd3eb1b0_1
#   tornado            conda-forge::tornado-6.1-py39hb9d737c~ --> pkgs/main::tornado-6.3.3-py39h5eee18b_0
#   typing-extensions  conda-forge/noarch::typing-extensions~ --> pkgs/main/linux-64::typing-extensions-4.9.0-py39h06a4308_1
#   typing_extensions  conda-forge/noarch::typing_extensions~ --> pkgs/main/linux-64::typing_extensions-4.9.0-py39h06a4308_1
#   zeromq               conda-forge::zeromq-4.3.4-h9c3ff4c_1 --> pkgs/main::zeromq-4.3.5-h6a678d5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   anyio              conda-forge/noarch::anyio-3.7.1-pyhd8~ --> pkgs/main/linux-64::anyio-3.5.0-py39h06a4308_0
#   argon2-cffi        conda-forge::argon2-cffi-23.1.0-pyhd8~ --> pkgs/main::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ conda-forge::argon2-cffi-bindings-21.~ --> pkgs/main::argon2-cffi-bindings-21.2.0-py39h7f8727e_0
#   asttokens          conda-forge::asttokens-2.4.0-pyhd8ed1~ --> pkgs/main::asttokens-2.0.5-pyhd3eb1b0_0
#   attrs              conda-forge/noarch::attrs-23.1.0-pyh7~ --> pkgs/main/linux-64::attrs-23.1.0-py39h06a4308_0
#   backcall           conda-forge::backcall-0.2.0-pyh9f0ad1~ --> pkgs/main::backcall-0.2.0-pyhd3eb1b0_0
#   backports.functoo~ conda-forge::backports.functools_lru_~ --> pkgs/main::backports.functools_lru_cache-1.6.4-pyhd3eb1b0_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.~ --> pkgs/main/linux-64::beautifulsoup4-4.12.2-py39h06a4308_0
#   bleach             conda-forge::bleach-6.0.0-pyhd8ed1ab_0 --> pkgs/main::bleach-4.1.0-pyhd3eb1b0_0
#   decorator          conda-forge::decorator-5.1.1-pyhd8ed1~ --> pkgs/main::decorator-5.1.1-pyhd3eb1b0_0
#   defusedxml         conda-forge::defusedxml-0.7.1-pyhd8ed~ --> pkgs/main::defusedxml-0.7.1-pyhd3eb1b0_0
#   entrypoints        conda-forge/noarch::entrypoints-0.4-p~ --> pkgs/main/linux-64::entrypoints-0.4-py39h06a4308_0
#   executing          conda-forge::executing-1.2.0-pyhd8ed1~ --> pkgs/main::executing-0.8.3-pyhd3eb1b0_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1~ --> pkgs/main/linux-64::idna-3.4-py39h06a4308_0
#   ipython            conda-forge/noarch::ipython-8.16.1-py~ --> pkgs/main/linux-64::ipython-8.15.0-py39h06a4308_0
#   ipython_genutils   conda-forge::ipython_genutils-0.2.0-p~ --> pkgs/main::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   jedi               conda-forge/noarch::jedi-0.19.1-pyhd8~ --> pkgs/main/linux-64::jedi-0.18.1-py39h06a4308_1
#   jupyter_server     conda-forge/noarch::jupyter_server-1.~ --> pkgs/main/linux-64::jupyter_server-1.23.4-py39h06a4308_0
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygmen~ --> pkgs/main/linux-64::jupyterlab_pygments-0.2.2-py39h06a4308_0
#   libsodium          conda-forge::libsodium-1.0.18-h36c2ea~ --> pkgs/main::libsodium-1.0.18-h7b6447c_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline~ --> pkgs/main/linux-64::matplotlib-inline-0.1.6-py39h06a4308_0
#   mistune            conda-forge/noarch::mistune-3.0.1-pyh~ --> pkgs/main/linux-64::mistune-2.0.4-py39h06a4308_0
#   nb_conda           conda-forge/noarch::nb_conda-2.2.1-un~ --> pkgs/main/linux-64::nb_conda-2.2.1-py39h06a4308_1
#   nb_conda_kernels   conda-forge::nb_conda_kernels-2.3.1-p~ --> pkgs/main::nb_conda_kernels-2.3.1-py39h06a4308_0
#   nbclassic          conda-forge/noarch::nbclassic-1.0.0-p~ --> pkgs/main/linux-64::nbclassic-1.0.0-py39h06a4308_0
#   nbclient           conda-forge/noarch::nbclient-0.8.0-py~ --> pkgs/main/linux-64::nbclient-0.8.0-py39h06a4308_0
#   nbformat           conda-forge/noarch::nbformat-5.9.2-py~ --> pkgs/main/linux-64::nbformat-5.9.2-py39h06a4308_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.~ --> pkgs/main/linux-64::nest-asyncio-1.5.6-py39h06a4308_0
#   notebook           conda-forge/noarch::notebook-6.5.6-py~ --> pkgs/main/linux-64::notebook-6.5.4-py39h06a4308_1
#   notebook-shim      conda-forge/noarch::notebook-shim-0.2~ --> pkgs/main/linux-64::notebook-shim-0.2.3-py39h06a4308_0
#   packaging          conda-forge/noarch::packaging-23.2-py~ --> pkgs/main/linux-64::packaging-23.1-py39h06a4308_0
#   pandocfilters      conda-forge::pandocfilters-1.5.0-pyhd~ --> pkgs/main::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso               conda-forge::parso-0.8.3-pyhd8ed1ab_0 --> pkgs/main::parso-0.8.3-pyhd3eb1b0_0
#   pickleshare        conda-forge::pickleshare-0.7.5-py_1003 --> pkgs/main::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-n~ --> pkgs/main/linux-64::pkgutil-resolve-name-1.3.10-py39h06a4308_1
#   platformdirs       conda-forge/noarch::platformdirs-3.11~ --> pkgs/main/linux-64::platformdirs-3.10.0-py39h06a4308_0
#   prometheus_client  conda-forge/noarch::prometheus_client~ --> pkgs/main/linux-64::prometheus_client-0.14.1-py39h06a4308_0
#   pure_eval          conda-forge::pure_eval-0.2.2-pyhd8ed1~ --> pkgs/main::pure_eval-0.2.2-pyhd3eb1b0_0
#   pycparser          conda-forge::pycparser-2.21-pyhd8ed1a~ --> pkgs/main::pycparser-2.21-pyhd3eb1b0_0
#   pygments           conda-forge/noarch::pygments-2.16.1-p~ --> pkgs/main/linux-64::pygments-2.15.1-py39h06a4308_1
#   python-dateutil    conda-forge::python-dateutil-2.8.2-py~ --> pkgs/main::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonsc~ --> pkgs/main/linux-64::python-fastjsonschema-2.16.2-py39h06a4308_0
#   send2trash         conda-forge/noarch::send2trash-1.8.2-~ --> pkgs/main/linux-64::send2trash-1.8.2-py39h06a4308_0
#   sniffio            conda-forge/noarch::sniffio-1.3.0-pyh~ --> pkgs/main/linux-64::sniffio-1.3.0-py39h06a4308_0
#   soupsieve          conda-forge/noarch::soupsieve-2.5-pyh~ --> pkgs/main/linux-64::soupsieve-2.5-py39h06a4308_0
#   stack_data         conda-forge::stack_data-0.6.2-pyhd8ed~ --> pkgs/main::stack_data-0.2.0-pyhd3eb1b0_0
#   terminado          conda-forge/noarch::terminado-0.17.1-~ --> pkgs/main/linux-64::terminado-0.17.1-py39h06a4308_0
#   tinycss2           conda-forge/noarch::tinycss2-1.2.1-py~ --> pkgs/main/linux-64::tinycss2-1.2.1-py39h06a4308_0
#   traitlets          conda-forge/noarch::traitlets-5.10.1-~ --> pkgs/main/linux-64::traitlets-5.7.1-py39h06a4308_0
#   wcwidth            conda-forge::wcwidth-0.2.8-pyhd8ed1ab~ --> pkgs/main::wcwidth-0.2.5-pyhd3eb1b0_0
#   webencodings       conda-forge/noarch::webencodings-0.5.~ --> pkgs/main/linux-64::webencodings-0.5.1-py39h06a4308_1
#   websocket-client   conda-forge/noarch::websocket-client-~ --> pkgs/main/linux-64::websocket-client-0.58.0-py39h06a4308_4
#   zipp               conda-forge/noarch::zipp-3.17.0-pyhd8~ --> pkgs/main/linux-64::zipp-3.17.0-py39h06a4308_0
#
#
#
# Downloading and Extracting Packages
# bleach-4.1.0         | 123 KB    | ##################################### | 100%
# mkl_fft-1.3.8        | 216 KB    | ##################################### | 100%
# mkl-service-2.4.0    | 54 KB     | ##################################### | 100%
# nest-asyncio-1.5.6   | 14 KB     | ##################################### | 100%
# argon2-cffi-21.3.0   | 15 KB     | ##################################### | 100%
# jsonschema-4.19.2    | 142 KB    | ##################################### | 100%
# parso-0.8.3          | 70 KB     | ##################################### | 100%
# mkl_random-1.2.4     | 313 KB    | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# mistune-2.0.4        | 92 KB     | ##################################### | 100%
# jupyter_core-5.5.0   | 76 KB     | ##################################### | 100%
# nbclient-0.8.0       | 97 KB     | ##################################### | 100%
# attrs-23.1.0         | 140 KB    | ##################################### | 100%
# psutil-5.9.0         | 330 KB    | ##################################### | 100%
# pytz-2023.3.post1    | 210 KB    | ##################################### | 100%
# tqdm-4.65.0          | 131 KB    | ##################################### | 100%
# ipykernel-6.25.0     | 228 KB    | ##################################### | 100%
# ipython_genutils-0.2 | 27 KB     | ##################################### | 100%
# bottleneck-1.3.5     | 115 KB    | ##################################### | 100%
# rpds-py-0.10.6       | 1007 KB   | ##################################### | 100%
# numba-0.59.0         | 4.4 MB    | ##################################### | 100%
# nbformat-5.9.2       | 136 KB    | ##################################### | 100%
# scipy-1.11.4         | 20.3 MB   | ##################################### | 100%
# platformdirs-3.10.0  | 33 KB     | ##################################### | 100%
# jsonschema-specifica | 15 KB     | ##################################### | 100%
# ipython-8.15.0       | 1.1 MB    | ##################################### | 100%
# jinja2-3.1.3         | 269 KB    | ##################################### | 100%
# python-dateutil-2.8. | 233 KB    | ##################################### | 100%
# llvmlite-0.42.0      | 3.7 MB    | ##################################### | 100%
# defusedxml-0.7.1     | 23 KB     | ##################################### | 100%
# soupsieve-2.5        | 69 KB     | ##################################### | 100%
# prometheus_client-0. | 90 KB     | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# tornado-6.3.3        | 635 KB    | ##################################### | 100%
# threadpoolctl-2.2.0  | 16 KB     | ##################################### | 100%
# jupyter_client-7.4.9 | 205 KB    | ##################################### | 100%
# ptyprocess-0.7.0     | 17 KB     | ##################################### | 100%
# pandas-2.1.4         | 12.4 MB   | ##################################### | 100%
# nb_conda_kernels-2.3 | 33 KB     | ##################################### | 100%
# wcwidth-0.2.5        | 26 KB     | ##################################### | 100%
# cffi-1.16.0          | 251 KB    | ##################################### | 100%
# libgfortran-ng-11.2. | 20 KB     | ##################################### | 100%
# nbconvert-7.10.0     | 472 KB    | ##################################### | 100%
# exceptiongroup-1.2.0 | 29 KB     | ##################################### | 100%
# pickleshare-0.7.5    | 13 KB     | ##################################### | 100%
# stack_data-0.2.0     | 22 KB     | ##################################### | 100%
# pyzmq-23.2.0         | 445 KB    | ##################################### | 100%
# tbb-2021.8.0         | 1.6 MB    | ##################################### | 100%
# prompt_toolkit-3.0.4 | 5 KB      | ##################################### | 100%
# referencing-0.30.2   | 61 KB     | ##################################### | 100%
# prompt-toolkit-3.0.4 | 571 KB    | ##################################### | 100%
# packaging-23.1       | 77 KB     | ##################################### | 100%
# joblib-1.2.0         | 396 KB    | ##################################### | 100%
# typing_extensions-4. | 54 KB     | ##################################### | 100%
# ca-certificates-2023 | 126 KB    | ##################################### | 100%
# importlib_resources- | 54 KB     | ##################################### | 100%
# send2trash-1.8.2     | 27 KB     | ##################################### | 100%
# decorator-5.1.1      | 12 KB     | ##################################### | 100%
# pexpect-4.8.0        | 53 KB     | ##################################### | 100%
# python-fastjsonschem | 231 KB    | ##################################### | 100%
# scikit-learn-1.3.0   | 8.4 MB    | ##################################### | 100%
# importlib-metadata-7 | 40 KB     | ##################################### | 100%
# pygments-2.15.1      | 1.7 MB    | ##################################### | 100%
# pkgutil-resolve-name | 10 KB     | ##################################### | 100%
# libsodium-1.0.18     | 244 KB    | ##################################### | 100%
# jupyter_server-1.23. | 382 KB    | ##################################### | 100%
# tinycss2-1.2.1       | 39 KB     | ##################################### | 100%
# entrypoints-0.4      | 16 KB     | ##################################### | 100%
# matplotlib-inline-0. | 16 KB     | ##################################### | 100%
# sniffio-1.3.0        | 16 KB     | ##################################### | 100%
# pure_eval-0.2.2      | 14 KB     | ##################################### | 100%
# backports-1.1        | 4 KB      | ##################################### | 100%
# pandocfilters-1.5.0  | 11 KB     | ##################################### | 100%
# terminado-0.17.1     | 31 KB     | ##################################### | 100%
# pynndescent-0.5.10   | 95 KB     | ##################################### | 100%
# notebook-shim-0.2.3  | 22 KB     | ##################################### | 100%
# executing-0.8.3      | 18 KB     | ##################################### | 100%
# six-1.16.0           | 18 KB     | ##################################### | 100%
# jedi-0.18.1          | 982 KB    | ##################################### | 100%
# libllvm14-14.0.6     | 33.4 MB   | ##################################### | 100%
# nbclassic-1.0.0      | 6.1 MB    | ##################################### | 100%
# libgfortran5-11.2.0  | 2.0 MB    | ##################################### | 100%
# zipp-3.17.0          | 21 KB     | ##################################### | 100%
# nbconvert-core-7.10. | 184 KB    | ##################################### | 100%
# asttokens-2.0.5      | 20 KB     | ##################################### | 100%
# anyio-3.5.0          | 167 KB    | ##################################### | 100%
# traitlets-5.7.1      | 200 KB    | ##################################### | 100%
# mkl-2023.1.0         | 171.5 MB  | ##################################### | 100%
# nb_conda-2.2.1       | 33 KB     | ##################################### | 100%
# typing-extensions-4. | 9 KB      | ##################################### | 100%
# jupyterlab_pygments- | 17 KB     | ##################################### | 100%
# numpy-base-1.26.3    | 7.2 MB    | ##################################### | 100%
# python-tzdata-2023.3 | 140 KB    | ##################################### | 100%
# argon2-cffi-bindings | 33 KB     | ##################################### | 100%
# backcall-0.2.0       | 13 KB     | ##################################### | 100%
# comm-0.1.2           | 13 KB     | ##################################### | 100%
# numexpr-2.8.7        | 140 KB    | ##################################### | 100%
# zeromq-4.3.5         | 366 KB    | ##################################### | 100%
# webencodings-0.5.1   | 20 KB     | ##################################### | 100%
# beautifulsoup4-4.12. | 209 KB    | ##################################### | 100%
# umap-learn-0.5.3     | 137 KB    | ##################################### | 100%
# debugpy-1.6.7        | 2.0 MB    | ##################################### | 100%
# numpy-1.26.3         | 10 KB     | ##################################### | 100%
# idna-3.4             | 93 KB     | ##################################### | 100%
# websocket-client-0.5 | 66 KB     | ##################################### | 100%
# notebook-6.5.4       | 532 KB    | ##################################### | 100%
# intel-openmp-2023.1. | 17.2 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /opt/python/3.9.15
#   uid: 10666
#   gid: 1203
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
data_path ='data'
input_path ='input'
res_dir ='output'
test_file ='GSE72056_full.csv'
moduleGene_file ='module_gene_complete_mouse_m168.csv'
cm_file ='cmMat_complete_mouse_c70_m168.csv'
sc_imputation =True
cName_file='cName_complete_mouse_c70_m168.csv'
fileName='output/ad1212_flux.csv'
balanceName='output/ad1212_balance.csv'
EPOCH=100

# Check if CUDA is available
cuda_available = torch.cuda.is_available()

print(f"CUDA available: {cuda_available}")

# If CUDA is available, print the number of CUDA devices and their names
if cuda_available:
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"CUDA Device {i}: {torch.cuda.get_device_name(i)}")


# choose cpu or gpu automatically
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print("now you are using device: ", device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 14
#      11 EPOCH=100
#      13 # Check if CUDA is available
# ---> 14 cuda_available = torch.cuda.is_available()
#      16 print(f"CUDA available: {cuda_available}")
#      18 # If CUDA is available, print the number of CUDA devices and their names
#
# NameError: name 'torch' is not defined

# %%
# read data
print("Starting load data...")
geneExpr = pd.read_csv(
            input_path + '/' + test_file,
            index_col=0)
geneExpr = geneExpr.T
geneExpr = geneExpr * 1.0
if sc_imputation == True:
    magic_operator = magic.MAGIC()
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        geneExpr = magic_operator.fit_transform(geneExpr)
if geneExpr.max().max() > 50:
    geneExpr = (geneExpr + 1).apply(np.log2)  
geneExprSum = geneExpr.sum(axis=1)
stand = geneExprSum.mean()
geneExprScale = geneExprSum / stand
geneExprScale = torch.FloatTensor(geneExprScale.values).to(device)

BATCH_SIZE = 2*geneExpr.shape[0]

# %%
geneExpr.head()

# %%
moduleGene = pd.read_csv(
            data_path + '/' + moduleGene_file,
            sep=',',
            index_col=0)
moduleLen = [moduleGene.iloc[i,:].notna().sum() for i in range(moduleGene.shape[0]) ]
moduleLen = np.array(moduleLen)

# find existing gene
module_gene_all = []
for i in range(moduleGene.shape[0]):
    for j in range(moduleGene.shape[1]):
        if pd.isna(moduleGene.iloc[i,j]) == False:
            module_gene_all.append(moduleGene.iloc[i,j])

# %%
moduleGene

# %%
print(module_gene_all[:10])

# %%
data_gene_all = geneExpr.columns

# Convert sets to lowercase
data_gene_all = [gene.lower() for gene in data_gene_all]
module_gene_all = [gene.lower() for gene in module_gene_all]

print("data_gene_all: ", sorted(data_gene_all))
print("module_gene_all: ", sorted(module_gene_all))
print("data_gene_all len: ", len(data_gene_all))
print("module_gene_all len: ", len(module_gene_all))

data_gene_all = set(data_gene_all)
module_gene_all = set(module_gene_all)
print("data_gene_all len: ", len(data_gene_all))
print("module_gene_all len: ", len(module_gene_all))

# %%
# Find intersection in lowercase
gene_overlap = list(data_gene_all.intersection(module_gene_all))
gene_overlap.sort()

# Optional: Map back to original case (choosing data_gene_all as source)
# gene_overlap = [gene for gene in data_gene_all if gene.lower() in gene_overlap]

print("Gene overlap:", gene_overlap)
print("Gene overlap len:", len(gene_overlap))

# %%
# Assuming gene_overlap is a list of genes you're interested in
missing_genes = [gene for gene in gene_overlap if gene not in data_gene_all]
print(f'missing_genes: {missing_genes}')
print(f'missing_genes len: {len(missing_genes)}')

# %%
cmMat = pd.read_csv(
        data_path + '/' + cm_file,
        sep=',',
        header=None)
cmMat = cmMat.values
print(cmMat[:5,:5])
cmMat = torch.FloatTensor(cmMat).to(device)

# %%
if cName_file != 'noCompoundName':
    print("Load compound name file, the balance output will have compound name.")
    cName = pd.read_csv(
            data_path + '/' + cName_file,
            sep=',',
            header=0)
    cName = cName.columns
print("Load data done.")
print(cName[:5])

# %%
gene_overlap

# %%
geneExpr.columns = geneExpr.columns.str.lower()
geneExpr

# %%
geneExpr[gene_overlap]

# %%
moduleGene

# %%
print("Starting process data...")
emptyNode = []
# extract overlap gene
geneExpr = geneExpr[gene_overlap] 
print(f'geneExpr: {geneExpr.head()}')

gene_names = geneExpr.columns
print(f'gene_names: {gene_names[:5]}')

cell_names = geneExpr.index.astype(str)
print(f'cell_names: {cell_names[:5]}')

n_modules = moduleGene.shape[0]
n_genes = len(gene_names)
n_cells = len(cell_names)
n_comps = cmMat.shape[0]
print(f'n_modules: {n_modules}, n_genes: {n_genes}, n_cells: {n_cells}, n_comps: {n_comps}')

geneExprDf = pd.DataFrame(columns = ['Module_Gene'] + list(cell_names))
print(geneExprDf)

# %%
geneExprDf

# %%
n_modules

# %%
for i in range(n_modules):
    genes = moduleGene.iloc[i,:].values.astype(str)
    genes = [g for g in genes if g != 'nan']
    if not genes:
        emptyNode.append(i)
        continue
    temp = geneExpr.copy()
    temp.loc[:, [g for g in gene_names if g not in genes]] = 0
    temp = temp.T
    temp['Module_Gene'] = ['%02d_%s' % (i,g) for g in gene_names]
    # geneExprDf = geneExprDf.append(temp, ignore_index = True, sort=False)
    geneExprDf = pd.concat([geneExprDf, temp], ignore_index=True, sort=False)
geneExprDf.index = geneExprDf['Module_Gene']
geneExprDf.drop('Module_Gene', axis = 'columns', inplace = True)

# %%
geneExprDf

# %%
X = geneExprDf.values.T
X = torch.FloatTensor(X).to(device)

# %%
df = geneExprDf
print(df.index[20:50])

# %%
df

# %%
len(df.index.unique())

# %%
#prepare data for constraint of module variation based on gene
df.index = [i.split('_')[0] for i in df.index]
df.index = df.index.astype(int)   # mush change type to ensure correct order, T column name order change!
#module_scale = df.groupby(df.index).sum(axis=1).T   # pandas version update

# %%
len(df.index.unique())

# %%
module_scale = df.groupby(df.index).sum().T  
module_scale = torch.FloatTensor(module_scale.values/ moduleLen) 
print("Process data done.")

# %%
# =============================================================================
#NN
torch.manual_seed(16)
print(f'X: {X.size()}, n_modules: {n_modules}, n_genes: {n_genes}')
net = FLUX(X, n_modules, f_in = n_genes, f_out = 1).to(device)
optimizer = torch.optim.Adam(net.parameters(), lr = LEARN_RATE)
# =============================================================================

# %%
#Dataloader
dataloader_params = {'batch_size': BATCH_SIZE,
                        'shuffle': False,
                        'num_workers': 0,
                        'pin_memory': False}
# dataloader_params = {
#     'batch_size': BATCH_SIZE,
#     'shuffle': True,  # Shuffling might be beneficial depending on the training regime
#     'num_workers': 4,  # Adjust based on your system's capabilities and the dataset size
#     'pin_memory': True,  # Helps with faster data transfer to CUDA devices
# }

dataSet = MyDataset(X, geneExprScale, module_scale)
train_loader = torch.utils.data.DataLoader(dataset=dataSet,
                                            **dataloader_params)

# %%
print("Starting train neural network...")
start = time.time()  
#   training
loss_v = []
loss_v1 = []
loss_v2 = []
loss_v3 = []
loss_v4 = []
net.train()
timestr = time.strftime("%Y%m%d-%H%M%S")
lossName = "./output/lossValue_" + timestr + ".txt"
file_loss = open(lossName, "a")

# %%
cmMat.size()

# %%
for epoch in tqdm(range(EPOCH)):
    loss, loss1, loss2, loss3, loss4 = 0,0,0,0,0
    # print(f'X: {X.size()}, X_scale: {X_scale.size()}, m_scale: {m_scale.size()}')
    for i, (X, X_scale, m_scale) in enumerate(train_loader):

        X_batch = Variable(X.float().to(device))
        X_scale_batch = Variable(X_scale.float().to(device))
        m_scale_batch = Variable(m_scale.float().to(device))
        
        out_m_batch, out_c_batch = net(X_batch, n_modules, n_genes, n_comps, cmMat)
        loss_batch, loss1_batch, loss2_batch, loss3_batch, loss4_batch  = myLoss(out_m_batch, out_c_batch, 
                                                                                    lamb1 = LAMB_BA, lamb2 = LAMB_NG, lamb3 = LAMB_CELL, lamb4 = LAMB_MOD, 
                                                                                    geneScale = X_scale_batch, moduleScale = m_scale_batch)

        optimizer.zero_grad()
        loss_batch.backward()
        optimizer.step()
        
        loss += loss_batch.cpu().data.numpy()
        loss1 += loss1_batch.cpu().data.numpy()
        loss2 += loss2_batch.cpu().data.numpy()
        loss3 += loss3_batch.cpu().data.numpy()
        loss4 += loss4_batch.cpu().data.numpy()
        
    #print('epoch: %02d, loss1: %.8f, loss2: %.8f, loss3: %.8f, loss4: %.8f, loss: %.8f' % (epoch+1, loss1, loss2, loss3, loss4, loss))
    file_loss.write('epoch: %02d, loss1: %.8f, loss2: %.8f, loss3: %.8f, loss4: %.8f, loss: %.8f. \n' % (epoch+1, loss1, loss2, loss3, loss4, loss))
    
    loss_v.append(loss)
    loss_v1.append(loss1)
    loss_v2.append(loss2)
    loss_v3.append(loss3)
    loss_v4.append(loss4)

# %%
end = time.time()
print("Training time: ", end - start) 

file_loss.close()
plt.plot(loss_v, '--')
plt.plot(loss_v1)
plt.plot(loss_v2)
plt.plot(loss_v3)
plt.plot(loss_v4)
plt.legend(['total', 'balance', 'negative', 'cellVar', 'moduleVar']);
imgName = './' + res_dir + '/loss_' + timestr + ".png"
plt.savefig(imgName)
timeName =  './' + res_dir + '/time_' + timestr + ".txt"
f = open(timeName, "a")
runTimeStr = str(end - start)
f.write(runTimeStr)
f.close()

# %%
#    Dataloader
dataloader_params = {'batch_size': 1,
                        'shuffle': False,
                        'num_workers': 0,
                        'pin_memory': False}

dataSet = MyDataset(X, geneExprScale, module_scale)
test_loader = torch.utils.data.DataLoader(dataset=dataSet,
                        **dataloader_params)

#testing
fluxStatuTest = np.zeros((n_cells, n_modules), dtype='f') #float32
balanceStatus = np.zeros((n_cells, n_comps), dtype='f')
net.eval()
for epoch in range(1):
    loss, loss1, loss2 = 0,0,0
    
    for i, (X, X_scale, _) in enumerate(test_loader):

        X_batch = Variable(X.float().to(device))
        out_m_batch, out_c_batch = net(X_batch, n_modules, n_genes, n_comps, cmMat)
        
        # save data
        # fluxStatuTest[i, :] = out_m_batch.detach().numpy()
        fluxStatuTest[i, :] = out_m_batch.detach().cpu().numpy()
        # balanceStatus[i, :] = out_c_batch.detach().numpy()
        balanceStatus[i, :] = out_c_batch.detach().cpu().numpy()

        
                

# save to file
if fileName == 'NULL':
    # user do not define file name of flux
    fileName = "./" + res_dir + "/" + test_file[-len(test_file):-4] + "_module" + str(n_modules) + "_cell" + str(n_cells) + "_batch" + str(BATCH_SIZE) + \
                "_LR" + str(LEARN_RATE) + "_epoch" + str(EPOCH) + "_SCimpute_" + str(sc_imputation)[0] + \
                "_lambBal" + str(LAMB_BA) + "_lambSca" + str(LAMB_NG) + "_lambCellCor" + str(LAMB_CELL) + "_lambModCor_1e-2" + \
                '_' + timestr + ".csv"
setF = pd.DataFrame(fluxStatuTest)
setF.columns = moduleGene.index
setF.index = geneExpr.index.tolist()
setF.to_csv(fileName)

setB = pd.DataFrame(balanceStatus)
setB.rename(columns = lambda x: x + 1)
setB.index = setF.index
if cName_file != 'noCompoundName':
    setB.columns = cName
if balanceName == 'NULL':
    # user do not define file name of balance
    balanceName = "./output/balance_" + timestr + ".csv"
setB.to_csv(balanceName)


print("scFEA job finished. Check result in the desired output folder.")
